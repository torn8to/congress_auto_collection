# %%
import pickle
import pandas as pd
import numpy as np
from pdf2image import convert_from_path
from House import housePTRentry

# %%
data = pickle.load(open('bulk_data.pkl','rb'))

# %%
data
# Out:
# ...
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
# ...
#  None,
#  None,
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
#  None,
# ...
#  None,
# ...
#  None,
#  None,
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
#  None,
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
